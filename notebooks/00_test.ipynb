# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn

print("funcionando 100%")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
# Out:
# funcionando 100%
# Pandas: 3.0.1
# Scikit-learn: 1.8.0
